# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_7n2o = pd.read_csv('7n2o_contacts.csv')

# %%
df_7n2o
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              28            D              0
# 1    CDR1 alpha     D              29            S              0
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 141  HLA alpha2     A             179            L              0
# 142  HLA alpha2     A             180            Q              0
# 143  HLA alpha2     A             181            R              0
# 144  HLA alpha2     A             182            A              0
# 145  HLA alpha2     A             183            D              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                 NaN                  NaN                       NaN
# 2                3.31                    M                       4.0
# 3                3.71                    M                       4.0
# 4                3.60                    M                       4.0
# ..                ...                  ...                       ...
# 141               NaN                  NaN                       NaN
# 142               NaN                  NaN                       NaN
# 143               NaN                  NaN                       NaN
# 144               NaN                  NaN                       NaN
# 145               NaN                  NaN                       NaN
#
# [146 rows x 8 columns]

# %%
df_7n2q = pd.read_csv('7n2q_contacts.csv')

# %%
df_7n2q
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              28            D              0
# 1    CDR1 alpha     D              29            S              0
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 135  HLA alpha2     A             179            L              0
# 136  HLA alpha2     A             180            Q              0
# 137  HLA alpha2     A             181            R              0
# 138  HLA alpha2     A             182            A              0
# 139  HLA alpha2     A             183            D              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                 NaN                  NaN                       NaN
# 2                3.71                    M                       4.0
# 3                3.51                    M                       4.0
# 4                3.67                    M                       4.0
# ..                ...                  ...                       ...
# 135               NaN                  NaN                       NaN
# 136               NaN                  NaN                       NaN
# 137               NaN                  NaN                       NaN
# 138               NaN                  NaN                       NaN
# 139               NaN                  NaN                       NaN
#
# [140 rows x 8 columns]

# %%
df_8cx4 = pd.read_csv('8cx4_contacts.csv')

# %%
df_8cx4
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              28            D              0
# 1    CDR1 alpha     D              29            S              0
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 141  HLA alpha2     A             179            L              0
# 142  HLA alpha2     A             180            Q              0
# 143  HLA alpha2     A             181            R              0
# 144  HLA alpha2     A             182            A              0
# 145  HLA alpha2     A             183            D              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                 NaN                  NaN                       NaN
# 2                3.59                    M                       4.0
# 3                3.91                    M                       4.0
# 4                3.51                    M                       4.0
# ..                ...                  ...                       ...
# 141               NaN                  NaN                       NaN
# 142               NaN                  NaN                       NaN
# 143               NaN                  NaN                       NaN
# 144               NaN                  NaN                       NaN
# 145               NaN                  NaN                       NaN
#
# [146 rows x 8 columns]

# %%
df_7n2q_2 = pd.read_csv('7n2q_L_B2702_norelax_contacts.csv')

# %%
df_7n2q_2
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              28            D              0
# 1    CDR1 alpha     D              29            S              0
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 145  HLA alpha2     A             179            L              0
# 146  HLA alpha2     A             180            Q              0
# 147  HLA alpha2     A             181            R              0
# 148  HLA alpha2     A             182            A              0
# 149  HLA alpha2     A             183            D              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                 NaN                  NaN                       NaN
# 2                2.95                    M                       4.0
# 3                3.43                    M                       4.0
# 4                2.71                    M                       4.0
# ..                ...                  ...                       ...
# 145               NaN                  NaN                       NaN
# 146               NaN                  NaN                       NaN
# 147               NaN                  NaN                       NaN
# 148               NaN                  NaN                       NaN
# 149               NaN                  NaN                       NaN
#
# [150 rows x 8 columns]

# %%
df_7n2o_2 = pd.read_csv('7n2o_L_B2702_norelax_contacts.csv')

# %%
df_7n2o_2
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              28            D              0
# 1    CDR1 alpha     D              29            S              0
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 152  HLA alpha2     A             179            L              0
# 153  HLA alpha2     A             180            Q              0
# 154  HLA alpha2     A             181            R              0
# 155  HLA alpha2     A             182            A              0
# 156  HLA alpha2     A             183            D              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                 NaN                  NaN                       NaN
# 2                2.89                    M                       4.0
# 3                3.83                    M                       4.0
# 4                2.34                    M                       4.0
# ..                ...                  ...                       ...
# 152               NaN                  NaN                       NaN
# 153               NaN                  NaN                       NaN
# 154               NaN                  NaN                       NaN
# 155               NaN                  NaN                       NaN
# 156               NaN                  NaN                       NaN
#
# [157 rows x 8 columns]

# %%
df_8cx4_2 = pd.read_csv('8cx4_L_B2702_norelax_contacts.csv')

# %%
df_8cx4_2
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              28            D              0
# 1    CDR1 alpha     D              29            S              1
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 151  HLA alpha2     A             179            L              0
# 152  HLA alpha2     A             180            Q              0
# 153  HLA alpha2     A             181            R              0
# 154  HLA alpha2     A             182            A              0
# 155  HLA alpha2     A             183            D              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                4.89                    M                       4.0
# 2                2.49                    M                       4.0
# 3                2.88                    M                       4.0
# 4                2.80                    M                       4.0
# ..                ...                  ...                       ...
# 151               NaN                  NaN                       NaN
# 152               NaN                  NaN                       NaN
# 153               NaN                  NaN                       NaN
# 154               NaN                  NaN                       NaN
# 155               NaN                  NaN                       NaN
#
# [156 rows x 8 columns]

# %% [markdown]
# **Посчитаем по всем CDR:**

# %%
target_regions = ['CDR1 alpha', 'CDR3 alpha', 'CDR3 beta']

total_contact_7n2q = df_7n2q[df_7n2q['Region'].isin(target_regions)]['Contact Count'].sum()
total_contact_7n2q_2 = df_7n2q_2[df_7n2q_2['Region'].isin(target_regions)]['Contact Count'].sum()
total_contact_7n2o = df_7n2o[df_7n2o['Region'].isin(target_regions)]['Contact Count'].sum()
total_contact_7n2o_2 = df_7n2o_2[df_7n2o_2['Region'].isin(target_regions)]['Contact Count'].sum()
total_contact_8cx4 = df_8cx4[df_8cx4['Region'].isin(target_regions)]['Contact Count'].sum()
total_contact_8cx4_2 = df_8cx4_2[df_8cx4_2['Region'].isin(target_regions)]['Contact Count'].sum()

# %%
summary_cdr = {'7n2o_B2705': total_contact_7n2o, '7n2o_B2702': total_contact_7n2o_2, '7n2q_B2705': total_contact_7n2q, '7n2q_B2702': total_contact_7n2q_2, '8cx4_B2705': total_contact_8cx4, '8cx4_B2702': total_contact_8cx4_2}
summary_cdr
# Out:
# {'7n2o_B2705': 18,
#  '7n2o_B2702': 21,
#  '7n2q_B2705': 18,
#  '7n2q_B2702': 18,
#  '8cx4_B2705': 20,
#  '8cx4_B2702': 22}

# %%
plot_df = pd.DataFrame(list(summary_cdr.items()), columns=['Structure', 'Contacts'])
plot_df
# Out:
#     Structure  Contacts
# 0  7n2o_B2705        18
# 1  7n2o_B2702        21
# 2  7n2q_B2705        18
# 3  7n2q_B2702        18
# 4  8cx4_B2705        20
# 5  8cx4_B2702        22

# %%
plt.figure(figsize=(10, 8))
sns.barplot(
    data=plot_df,
    x='Structure',
    y='Contacts',
    hue='Structure',         
    palette='pastel',
    edgecolor='black',
    legend=False             
)
plt.ylabel('Total Contacts')
plt.title('Сумма контактов по CDR')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Посчитаем отдельно по каждому CDR:**

# %%
target_regions = ['CDR1 alpha', 'CDR3 alpha', 'CDR3 beta']
structures = ['7n2o', '7n2o_2', '7n2q', '7n2q_2', '8cx4', '8cx4_2']
results = []

for struct in structures:
    df_name = f'df_{struct}'
    df = globals().get(df_name)


    for region in target_regions:
        total_contact = df[df['Region'] == region]['Contact Count'].sum()
        results.append({'Structure': struct, 'Region': region, 'TotalContact': total_contact})

summary_df = pd.DataFrame(results)
summary_df
# Out:
#    Structure      Region  TotalContact
# 0       7n2o  CDR1 alpha             5
# 1       7n2o  CDR3 alpha             3
# 2       7n2o   CDR3 beta            10
# 3     7n2o_2  CDR1 alpha             5
# 4     7n2o_2  CDR3 alpha             3
# 5     7n2o_2   CDR3 beta            13
# 6       7n2q  CDR1 alpha             5
# 7       7n2q  CDR3 alpha             1
# 8       7n2q   CDR3 beta            12
# 9     7n2q_2  CDR1 alpha             5
# 10    7n2q_2  CDR3 alpha             1
# 11    7n2q_2   CDR3 beta            12
# 12      8cx4  CDR1 alpha             5
# 13      8cx4  CDR3 alpha             4
# 14      8cx4   CDR3 beta            11
# 15    8cx4_2  CDR1 alpha             6
# 16    8cx4_2  CDR3 alpha             4
# 17    8cx4_2   CDR3 beta            12

# %%
regions = summary_df['Region'].unique()

fig, axes = plt.subplots(nrows=1, ncols=len(regions), figsize=(5 * len(regions), 5), sharey=True)

if len(regions) == 1:
    axes = [axes]

for ax, region in zip(axes, regions):
    region_df = summary_df[summary_df['Region'] == region]
    sns.barplot(
        data=region_df,
        x='Structure',
        y='TotalContact',
        hue='Structure',          
        palette='pastel',
        edgecolor='black',
        ax=ax,
        legend=False             
    )
    ax.set_title(region)
    ax.set_ylabel('Total Contacts')
    ax.set_xlabel('Structure')
    ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# **Посчитаем по HLA (суммарно по двум альфа-спиралям):**

# %%
target_regions = ['HLA alpha1', 'HLA alpha2']
structures = ['7n2o', '7n2o_2', '7n2q', '7n2q_2', '8cx4', '8cx4_2']
results = []

for struct in structures:
    df_name = f'df_{struct}'
    df = globals().get(df_name)


    for region in target_regions:
        total_contact = df[df['Region'] == region]['Contact Count'].sum()
        results.append({'Structure': struct, 'Region': region, 'TotalContact': total_contact})

summary_df_hla = pd.DataFrame(results)
hla_total_df = (
    summary_df_hla
    .groupby('Structure')['TotalContact']
    .sum()
    .reset_index()
    .rename(columns={'TotalContact': 'HLA_TotalContact'})
)
hla_total_df
# Out:
#   Structure  HLA_TotalContact
# 0      7n2o                41
# 1    7n2o_2                54
# 2      7n2q                40
# 3    7n2q_2                54
# 4      8cx4                40
# 5    8cx4_2                54

# %%
plt.figure(figsize=(10, 8))
sns.barplot(
    data=hla_total_df,
    x='Structure',
    y='HLA_TotalContact',
    hue='Structure',         
    palette='pastel',
    edgecolor='black',
    legend=False             
)
plt.ylabel('Total Contacts')
plt.title('HLA-peptide')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Разницы контактов:**
#
# delta = structure_B2702 - structure_B2705

# %%
structure_pairs = [
    ('7n2o', '7n2o_2'),
    ('7n2q', '7n2q_2'),
    ('8cx4', '8cx4_2'),
]

delta_results = []

for base, alt in structure_pairs:
    base_val = hla_total_df[hla_total_df['Structure'] == base]['HLA_TotalContact'].iloc[0]
    alt_val = hla_total_df[hla_total_df['Structure'] == alt]['HLA_TotalContact'].iloc[0]

    delta = alt_val - base_val  # delta = structure_B2702 - structure_B2705

    delta_results.append({
        'Structure': base,
        'Delta': delta
    })

delta_df_hla = pd.DataFrame(delta_results)

# %%
structure_pairs = [
    ('7n2o', '7n2o_2'),
    ('7n2q', '7n2q_2'),
    ('8cx4', '8cx4_2'),
]

delta_results = []

for base, alt in structure_pairs:
    df_base = summary_df[summary_df['Structure'] == base].set_index('Region')
    df_alt = summary_df[summary_df['Structure'] == alt].set_index('Region')

    common_regions = df_base.index.intersection(df_alt.index)

    for region in common_regions:
        delta = df_alt.loc[region, 'TotalContact'] - df_base.loc[region, 'TotalContact']
        delta_results.append({
            'Structure': base,
            'Region': region,
            'Delta': delta
        })

delta_df = pd.DataFrame(delta_results)

# %%
delta_df_hla['Region'] = 'HLA'

delta_df = pd.concat([delta_df, delta_df_hla], ignore_index=True)
delta_df
# Out:
#    Structure      Region  Delta
# 0       7n2o  CDR1 alpha      0
# 1       7n2o  CDR3 alpha      0
# 2       7n2o   CDR3 beta      3
# 3       7n2q  CDR1 alpha      0
# 4       7n2q  CDR3 alpha      0
# 5       7n2q   CDR3 beta      0
# 6       8cx4  CDR1 alpha      1
# 7       8cx4  CDR3 alpha      0
# 8       8cx4   CDR3 beta      1
# 9       7n2o         HLA     13
# 10      7n2q         HLA     14
# 11      8cx4         HLA     14

# %% [markdown]
# **Посчитаем через коэффициенты энергий TCRen:**

# %%
energy_df = pd.read_csv("TCRen_potential.csv")
energy_df
# Out:
#     residue.aa.from residue.aa.to     TCRen
# 0                 A             A -0.159822
# 1                 A             C -0.226424
# 2                 A             D  0.921459
# 3                 A             E  0.044066
# 4                 A             F  0.018394
# ..              ...           ...       ...
# 375               Y             S  0.479961
# 376               Y             T  0.539116
# 377               Y             V -0.204149
# 378               Y             W -0.556273
# 379               Y             Y -0.068726
#
# [380 rows x 3 columns]

# %%
structure_list = ['7n2o', '7n2o_2', '7n2q', '7n2q_2', '8cx4', '8cx4_2']  
result_by_structure = {}

for structure in structure_list:
    df = globals()[f'df_{structure}']
    df.columns = ['Region', 'Chain', 'Residue Number', 'residue.aa.from',
                  'Contact Count', 'Min Distance (Å)', 'residue.aa.to',
                  'Contacted Peptide Number']
    
    merged_df = pd.merge(df, energy_df, on=['residue.aa.from', 'residue.aa.to'], how='inner')
    merged_df['Energy'] = merged_df['TCRen'] * merged_df['Contact Count']

    energy_sum = merged_df.groupby("Region")["Energy"].sum().reset_index()

    result_by_structure[structure] = energy_sum

# %%
all_energy_df = pd.concat(
    [
        df.assign(Structure=structure)
        for structure, df in result_by_structure.items()
    ],
    ignore_index=True
)

all_energy_df = all_energy_df[['Structure', 'Region', 'Energy']]

# %%
all_energy_df
# Out:
#    Structure      Region    Energy
# 0       7n2o  CDR1 alpha -0.272731
# 1       7n2o  CDR3 alpha -0.617742
# 2       7n2o   CDR3 beta -0.554961
# 3       7n2o  HLA alpha1  0.015214
# 4       7n2o  HLA alpha2  0.371038
# 5     7n2o_2  CDR1 alpha -0.272731
# 6     7n2o_2  CDR3 alpha -0.617742
# 7     7n2o_2   CDR3 beta -1.067236
# 8     7n2o_2  HLA alpha1  0.149080
# 9     7n2o_2  HLA alpha2  1.492580
# 10      7n2q  CDR1 alpha -0.272731
# 11      7n2q  CDR3 alpha  0.156518
# 12      7n2q   CDR3 beta -0.153919
# 13      7n2q  HLA alpha1  0.015214
# 14      7n2q  HLA alpha2  0.267032
# 15    7n2q_2  CDR1 alpha -0.272731
# 16    7n2q_2  CDR3 alpha  0.156518
# 17    7n2q_2   CDR3 beta -0.153919
# 18    7n2q_2  HLA alpha1  0.149080
# 19    7n2q_2  HLA alpha2  1.492580
# 20      8cx4  CDR1 alpha -0.272731
# 21      8cx4  CDR3 alpha -0.607740
# 22      8cx4   CDR3 beta -0.415847
# 23      8cx4  HLA alpha1  0.015214
# 24      8cx4  HLA alpha2  0.401482
# 25    8cx4_2  CDR1 alpha -0.294483
# 26    8cx4_2  CDR3 alpha -0.607740
# 27    8cx4_2   CDR3 beta -0.459478
# 28    8cx4_2  HLA alpha1  0.149080
# 29    8cx4_2  HLA alpha2  1.492580

# %%
grouped = all_energy_df.groupby(['Structure', 'Region'], as_index=False)['Energy'].sum()

hla_grouped = grouped[grouped['Region'].isin(['HLA alpha1', 'HLA alpha2'])]

hla_summed = hla_grouped.groupby('Structure', as_index=False)['Energy'].sum()
hla_summed['Region'] = 'HLA'

non_hla = grouped[~grouped['Region'].isin(['HLA alpha1', 'HLA alpha2'])]

all_energy_df = pd.concat([non_hla, hla_summed], ignore_index=True)

all_energy_df = all_energy_df[['Structure', 'Region', 'Energy']]

# %%
all_energy_df
# Out:
#    Structure      Region    Energy
# 0       7n2o  CDR1 alpha -0.272731
# 1       7n2o  CDR3 alpha -0.617742
# 2       7n2o   CDR3 beta -0.554961
# 3     7n2o_2  CDR1 alpha -0.272731
# 4     7n2o_2  CDR3 alpha -0.617742
# 5     7n2o_2   CDR3 beta -1.067236
# 6       7n2q  CDR1 alpha -0.272731
# 7       7n2q  CDR3 alpha  0.156518
# 8       7n2q   CDR3 beta -0.153919
# 9     7n2q_2  CDR1 alpha -0.272731
# 10    7n2q_2  CDR3 alpha  0.156518
# 11    7n2q_2   CDR3 beta -0.153919
# 12      8cx4  CDR1 alpha -0.272731
# 13      8cx4  CDR3 alpha -0.607740
# 14      8cx4   CDR3 beta -0.415847
# 15    8cx4_2  CDR1 alpha -0.294483
# 16    8cx4_2  CDR3 alpha -0.607740
# 17    8cx4_2   CDR3 beta -0.459478
# 18      7n2o         HLA  0.386252
# 19    7n2o_2         HLA  1.641660
# 20      7n2q         HLA  0.282246
# 21    7n2q_2         HLA  1.641660
# 22      8cx4         HLA  0.416696
# 23    8cx4_2         HLA  1.641660

# %% [markdown]
# **Разницы энергий TCRen:**
#
# delta=structure_2 (B2702) - structure (B2705)

# %%
structure_pairs = [
    ('7n2o', '7n2o_2'),
    ('7n2q', '7n2q_2'),
    ('8cx4', '8cx4_2')
]

structure_energy_map = {
    struct: all_energy_df[all_energy_df['Structure'] == struct].set_index('Region')
    for struct in all_energy_df['Structure'].unique()
}

delta_energy_rows = []

for struct1, struct2 in structure_pairs:
    df1 = structure_energy_map.get(struct1)
    df2 = structure_energy_map.get(struct2)
    
    if df1 is None or df2 is None:
        continue

    merged = df1[['Energy']].rename(columns={'Energy': 'Energy_1'}).join(
        df2[['Energy']].rename(columns={'Energy': 'Energy_2'}),
        how='inner'
    )
#delta=structure_2 (B2702) - structure (B2705)

    merged['Delta_Energy'] = merged['Energy_2'] - merged['Energy_1']
    merged['Structure_1'] = struct1
    merged['Structure_2'] = struct2
    merged = merged.reset_index()[['Region', 'Structure_1', 'Structure_2', 'Delta_Energy']]
    
    delta_energy_rows.append(merged)
delta_energy_df = pd.concat(delta_energy_rows, ignore_index=True)

# %%
delta_energy_df
# Out:
#         Region Structure_1 Structure_2  Delta_Energy
# 0   CDR1 alpha        7n2o      7n2o_2  0.000000e+00
# 1   CDR3 alpha        7n2o      7n2o_2  0.000000e+00
# 2    CDR3 beta        7n2o      7n2o_2 -5.122754e-01
# 3          HLA        7n2o      7n2o_2  1.255408e+00
# 4   CDR1 alpha        7n2q      7n2q_2  0.000000e+00
# 5   CDR3 alpha        7n2q      7n2q_2  0.000000e+00
# 6    CDR3 beta        7n2q      7n2q_2 -2.775558e-17
# 7          HLA        7n2q      7n2q_2  1.359414e+00
# 8   CDR1 alpha        8cx4      8cx4_2 -2.175133e-02
# 9   CDR3 alpha        8cx4      8cx4_2  0.000000e+00
# 10   CDR3 beta        8cx4      8cx4_2 -4.363011e-02
# 11         HLA        8cx4      8cx4_2  1.224964e+00

# %% [markdown]
# **Разница множеств контактов**

# %%
def extract_contact_set(df):
    df_filtered = df[df['residue.aa.to'].notna()]
    return set(zip(
        df_filtered['Region'],
        df_filtered['Chain'],
        df_filtered['Residue Number'],
        df_filtered['residue.aa.from'],
        df_filtered['residue.aa.to'],
        df_filtered['Contacted Peptide Number']
    ))

# %%
structure_pairs = [
    ('7n2o', '7n2o_2'),
    ('7n2q', '7n2q_2'),
    ('8cx4', '8cx4_2')
]


all_results = []

for struct1, struct2 in structure_pairs:
    df1 = globals()[f'df_{struct1}']
    df2 = globals()[f'df_{struct2}']

    set1 = extract_contact_set(df1)
    set2 = extract_contact_set(df2)

    union_contacts = set1 | set2

    for contact in union_contacts:
        all_results.append({
            'Region': contact[0],
            'Chain': contact[1],
            'Residue Number': contact[2],
            'residue.aa.from': contact[3],
            'residue.aa.to': contact[4],
            'Contacted Peptide Number': contact[5],
            'In_structure_1': contact in set1,
            'In_structure_2': contact in set2,
            'Structure_1_name': struct1,
            'Structure_2_name': struct2
        })

result_df = pd.DataFrame(all_results)

# %%
result_df
# Out:
#          Region Chain  Residue Number residue.aa.from residue.aa.to  \
# 0    HLA alpha1     A              77               N             F
# 1     CDR3 beta     F              97               L             P
# 2    HLA alpha1     A              66               I             M
# 3    CDR1 alpha     D              31               I             M
# 4    HLA alpha1     A              76               E             P
# ..          ...   ...             ...             ...           ...
# 236  HLA alpha1     A              63               E             L
# 237  HLA alpha1     A              73               T             F
# 238  HLA alpha1     A              72               Q             L
# 239  HLA alpha1     A              73               T             P
# 240  HLA alpha1     A              70               K             R
#
#      Contacted Peptide Number  In_structure_1  In_structure_2  \
# 0                         9.0           False            True
# 1                         8.0            True            True
# 2                         5.0           False            True
# 3                         4.0            True            True
# 4                         8.0            True            True
# ..                        ...             ...             ...
# 236                       1.0            True            True
# 237                       9.0           False            True
# 238                       6.0           False            True
# 239                       8.0            True            True
# 240                       2.0           False            True
#
#     Structure_1_name Structure_2_name
# 0               7n2o           7n2o_2
# 1               7n2o           7n2o_2
# 2               7n2o           7n2o_2
# 3               7n2o           7n2o_2
# 4               7n2o           7n2o_2
# ..               ...              ...
# 236             8cx4           8cx4_2
# 237             8cx4           8cx4_2
# 238             8cx4           8cx4_2
# 239             8cx4           8cx4_2
# 240             8cx4           8cx4_2
#
# [241 rows x 10 columns]

# %%
result_df.to_csv('diff_set_contacts.csv')
